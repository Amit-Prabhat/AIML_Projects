# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('C:\\Users\\Hp\\Desktop\\automobile\\Automobile.csv')

# %%
df
# Out:
#    Name of the image Color of the car Manufacturer of the car  \
# 0           download            White                    Audi
# 1       download (1)            White                    Audi
# 2       download (2)            White                    Audi
# 3       download (3)            White                    Audi
# 4                  4            Black                   Acura
# 5                  3            Black                   Acura
# 6                  1            Black                   Acura
# 7                 87              Red      Chrysler Group LLC
# 8                 54              Red      Chrysler Group LLC
# 9                546              Red                 Hyundai
# 10               654              Red                 Hyundai
# 11              5464              Red                 Hyundai
# 12              5454            Black                    Ford
# 13              8756            White                    Ford
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import os
import cv2

# %%
# !pip install opencv-contrib-python-headless

# %%
auto_path= 'C:\\Users\\Hp\\Desktop\\automobile'

# %%
auto_path_audi= auto_path+'\\Audi TT'
auto_path_acura=auto_path+'\\Acura TL'
auto_path_buick= auto_path+'\\buick verano'
auto_path_dodged=auto_path+'\\Dodge Dakota'
auto_path_dodgej=auto_path+'\\dodge journey'
auto_path_ford= auto_path+'\\Ford Super duty'
auto_path_geo= auto_path+'\\Geo metro'
auto_path_hyundai= auto_path+'\\Hyundai Sonata Hybrid'
