# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from  tensorflow.keras.layers import Flatten, Dense
from pandas import DataFrame
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tkinter as tk
from tkinter import ttk
import pandas as pd 
import re
import warnings;
warnings.simplefilter('ignore')

main_window= tk.Tk()
main_window.title('Neural Network GUI'.center(110))
main_window.geometry("600x250")



# importing data 
Name= ttk. Label(main_window,text = "Step 1: File Name")
Name.grid(row=0, column=0)

Name_var=tk.StringVar()
Name_entrybox= ttk.Entry(main_window, width = 16, textvariable= Name_var)
Name_entrybox.grid(row=0, column=1)

def Import_data():
    global DB
    Df_Name= Name_var.get()
    DB=pd.read_csv(Df_Name)
    Confirmation ="Done"
    Confirmation_box=ttk.Entry(main_window, width=16)
    Confirmation_box.grid(row=0, column=3)
    Confirmation_box.insert(1, str(Confirmation))

Import_DataButton=ttk.Button(main_window, text='Import Data', command = Import_data).grid(row=0, column=2)


# importing Target
Name1= ttk. Label(main_window,text = "Step 2: Target Column")
Name1.grid(row=1, column=0)

Name1_var=tk.StringVar()
Name1_entrybox= ttk.Entry(main_window, width = 16, textvariable= Name1_var)
Name1_entrybox.grid(row=1, column=1)

def Import_target():
    target_Name= Name1_var.get()
    c=0
    for col in DB.columns:
        if (col == target_Name):
            Confirmation1 ="Found"
            c=1
    if (c == 0):
        Confirmation1 ="Not Found"  
        
    Confirmation1_box=ttk.Entry(main_window, width=16)
    Confirmation1_box.grid(row=1, column=3)
    Confirmation1_box.insert(1, str(Confirmation1))

Import_TargetButton=ttk.Button(main_window, text='Import Target', command = Import_target).grid(row=1, column=2)


#------------------------------------Step3-----------------------------------------------
# Neural Network Regressor
Name2= ttk. Label(main_window,text = "Step 3: Neural Network Regressor")
Name2.grid(row=2, column=0)

# Neural Network Regressor Train
Name3= ttk. Label(main_window,text = "Regression")
Name3.grid(row=3, column=0)

def Train_model():
    #Prepare Data
    x=DB.drop(['Signal_Strength'],axis=1)
    y=DB['Signal_Strength']

    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.25, random_state=42)


    #Removing the outliers
    from pandas import DataFrame
    from sklearn.preprocessing import PowerTransformer
    clmn=x_train.columns
    pt = PowerTransformer()
    x_train = pt.fit_transform(x_train)
    x_train = DataFrame(x_train)
    x_train.columns=clmn

    #Removing the outliers
    from pandas import DataFrame
    from sklearn.preprocessing import PowerTransformer
    clmn=x_test.columns
    pt = PowerTransformer()
    x_test = pt.fit_transform(x_test)
    x_test = DataFrame(x_test)
    x_test.columns=clmn

    # Standard Scalar
    sc=StandardScaler()

    Xnew_train= sc.fit_transform(x_train)
    Xnew_test=sc.transform(x_test)

    ynew_train = y_train.to_numpy()
    ynew_test=y_test.to_numpy()
    
    
    # Initialize Sequential model
    global model_reg
    model_reg = tf.keras.Sequential()
    # Normalize input data
    model_reg.add(tf.keras.layers.BatchNormalization(input_shape=(11,)))
    model_reg.add(tf.keras.layers.Dense(300, activation= "relu"))
    model_reg.add(tf.keras.layers.Dense(121, activation= "relu"))
    model_reg.add(tf.keras.layers.Dropout(0.25))
    # Add final Dense layer for prediction
    model_reg.add(tf.keras.layers.Dense(1))
    model_reg.compile(optimizer='adam', loss='mse',metrics=['mae'])
 
    #Fit model
    model_reg.fit(Xnew_train, ynew_train, validation_data=(Xnew_test,ynew_test),epochs=50, batch_size=10)
    
    
    Confirmation3 ="Network Trained"  
        
    Confirmation3_box=ttk.Entry(main_window, width=20)
    Confirmation3_box.grid(row=3, column=2)
    Confirmation3_box.insert(1, str(Confirmation3))

Train_Button=ttk.Button(main_window, text='Train', command = Train_model).grid(row=3, column=1)

# Neural Network Regressor Pickle
Name4= ttk. Label(main_window,text = "Pickle")
Name4.grid(row=4, column=0)

def Save_model():
    
    model_reg.save("signal_strength_quality_regressormodel.h5")
    
    Confirmation4 ="Saved model to disk"  
        
    Confirmation4_box=ttk.Entry(main_window, width=20)
    Confirmation4_box.grid(row=4, column=2)
    Confirmation4_box.insert(1, str(Confirmation4))

Save_Button=ttk.Button(main_window, text='Run', command = Save_model).grid(row=4, column=1)


#-----------------------------Preparing data for classifier------------------
def Prepare_class_data():
    Prepare_data()
    from tensorflow.keras.utils import to_categorical
    yc = to_categorical(y, num_classes= 9)
    Xc_train, Xc_test, yc_train, yc_test = train_test_split(x, yc, test_size=.30, random_state=42)


#------------------------------------Step4-----------------------------------------------
# Neural Network Classifier
Name5= ttk. Label(main_window,text = "Step 4: Neural Network Classifier")
Name5.grid(row=5, column=0)

# Neural Network Classifier Train
Name6= ttk. Label(main_window,text = "Classifier")
Name6.grid(row=6, column=0)

def Train6_model():
    x=DB.drop(['Signal_Strength'],axis=1)
    y=DB['Signal_Strength']

    from sklearn.model_selection import train_test_split
    from tensorflow.keras.utils import to_categorical
    yc = to_categorical(y, num_classes= 9)
    Xc_train, Xc_test, yc_train, yc_test = train_test_split(x, yc, test_size=.30, random_state=42)
    


    #Removing the outliers
    from pandas import DataFrame
    from sklearn.preprocessing import PowerTransformer
    clmn=Xc_train.columns
    pt = PowerTransformer()
    Xc_train = pt.fit_transform(Xc_train)
    Xc_train = DataFrame(Xc_train)
    Xc_train.columns=clmn

    #Removing the outliers
    from pandas import DataFrame
    from sklearn.preprocessing import PowerTransformer
    clmn=Xc_test.columns
    pt = PowerTransformer()
    Xc_test = pt.fit_transform(Xc_test)
    Xc_test = DataFrame(Xc_test)
    Xc_test.columns=clmn

    # Standard Scalar
    sc=StandardScaler()

    Xnew_train= sc.fit_transform(Xc_train)
    Xnew_test=sc.transform(Xc_test)

    
    global model_class
    model_class = tf.keras.models.Sequential()
    model_class.add(Dense(200, activation='relu'))
    model_class.add(Dense(100, activation='relu'))
    model_class.add(tf.keras.layers.Dropout(0.25))
    model_class.add(Dense(9, activation='softmax'))
    
    earlystopping= tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience= 2,restore_best_weights= True)
    
    # Compile the model
    model_class.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")

    # Fit the model
    model_class.fit(x=Xc_train, y=yc_train, validation_data=(Xc_test,yc_test),epochs=50, batch_size=32, callbacks=earlystopping)
 
    
    Confirmation6 ="Network Trained"  
        
    Confirmation6_box=ttk.Entry(main_window, width=20)
    Confirmation6_box.grid(row=6, column=2)
    Confirmation6_box.insert(1, str(Confirmation6))

Train6_Button=ttk.Button(main_window, text='Train', command = Train6_model).grid(row=6, column=1)

# Neural Network Classifier Pickle
Name7= ttk. Label(main_window,text = "Pickle")
Name7.grid(row=7, column=0)

def Save7_model():
    model_class.save("signal_strength_quality_Classificationmodel.h5")
    
    Confirmation7 ="Saved model to disk"  
        
    Confirmation7_box=ttk.Entry(main_window, width=20)
    Confirmation7_box.grid(row=7, column=2)
    Confirmation7_box.insert(1, str(Confirmation7))

Save7_Button=ttk.Button(main_window, text='Run', command = Save7_model).grid(row=7, column=1)

    


main_window.mainloop()
# Out:
# Epoch 1/50
# 120/120 [==============================] - 1s 3ms/step - loss: 4.4818 - mae: 1.6119 - val_loss: 1.9649 - val_mae: 1.1248
# Epoch 2/50
# 120/120 [==============================] - 0s 2ms/step - loss: 1.6336 - mae: 1.0108 - val_loss: 1.2547 - val_mae: 0.9075
# Epoch 3/50
# 120/120 [==============================] - 0s 2ms/step - loss: 1.2478 - mae: 0.8794 - val_loss: 0.8905 - val_mae: 0.7530
# Epoch 4/50
# 120/120 [==============================] - 0s 2ms/step - loss: 1.0524 - mae: 0.8105 - val_loss: 0.7233 - val_mae: 0.6836
# Epoch 5/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.9168 - mae: 0.7569 - val_loss: 0.9045 - val_mae: 0.7456
# Epoch 6/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.8017 - mae: 0.6867 - val_loss: 0.5596 - val_mae: 0.5878
# Epoch 7/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.7451 - mae: 0.6834 - val_loss: 0.4178 - val_mae: 0.5306
# Epoch 8/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.7034 - mae: 0.6546 - val_loss: 0.4869 - val_mae: 0.5491
# Epoch 9/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6695 - mae: 0.6482 - val_loss: 0.3917 - val_mae: 0.4886
# Epoch 10/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6541 - mae: 0.6374 - val_loss: 0.3934 - val_mae: 0.4856
# Epoch 11/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6624 - mae: 0.6337 - val_loss: 0.5012 - val_mae: 0.5653
# Epoch 12/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6660 - mae: 0.6364 - val_loss: 0.4297 - val_mae: 0.5149
# Epoch 13/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6940 - mae: 0.6527 - val_loss: 0.4072 - val_mae: 0.5050
# Epoch 14/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6261 - mae: 0.6210 - val_loss: 0.4663 - val_mae: 0.5416
# Epoch 15/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6410 - mae: 0.6287 - val_loss: 0.5753 - val_mae: 0.6081
# Epoch 16/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6747 - mae: 0.6416 - val_loss: 0.4526 - val_mae: 0.5390
# Epoch 17/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6126 - mae: 0.6096 - val_loss: 0.3962 - val_mae: 0.4996
# Epoch 18/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6218 - mae: 0.6182 - val_loss: 0.4300 - val_mae: 0.5083
# Epoch 19/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6088 - mae: 0.6136 - val_loss: 0.4079 - val_mae: 0.5084
# Epoch 20/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6928 - mae: 0.6457 - val_loss: 0.4514 - val_mae: 0.5337
# Epoch 21/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6359 - mae: 0.6190 - val_loss: 0.4066 - val_mae: 0.5088
# Epoch 22/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6120 - mae: 0.6182 - val_loss: 0.5013 - val_mae: 0.5681
# Epoch 23/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6142 - mae: 0.6139 - val_loss: 0.3605 - val_mae: 0.4834
# Epoch 24/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6568 - mae: 0.6392 - val_loss: 0.3985 - val_mae: 0.5166
# Epoch 25/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5827 - mae: 0.6029 - val_loss: 0.4173 - val_mae: 0.5071
# Epoch 26/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6197 - mae: 0.6144 - val_loss: 0.3698 - val_mae: 0.4860
# Epoch 27/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6197 - mae: 0.6229 - val_loss: 0.3703 - val_mae: 0.4851
# Epoch 28/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5977 - mae: 0.6101 - val_loss: 0.3835 - val_mae: 0.4916
# Epoch 29/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6171 - mae: 0.6064 - val_loss: 0.3601 - val_mae: 0.4878
# Epoch 30/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5990 - mae: 0.6056 - val_loss: 0.3690 - val_mae: 0.4768
# Epoch 31/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5454 - mae: 0.5802 - val_loss: 0.4493 - val_mae: 0.5300
# Epoch 32/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5742 - mae: 0.5952 - val_loss: 0.3896 - val_mae: 0.4864
# Epoch 33/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5971 - mae: 0.6122 - val_loss: 0.3771 - val_mae: 0.4918
# Epoch 34/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6053 - mae: 0.6177 - val_loss: 0.3571 - val_mae: 0.4666
# Epoch 35/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5956 - mae: 0.6070 - val_loss: 0.3702 - val_mae: 0.4834
# Epoch 36/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5889 - mae: 0.6044 - val_loss: 0.4565 - val_mae: 0.5363
# Epoch 37/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5918 - mae: 0.6015 - val_loss: 0.3643 - val_mae: 0.4729
# Epoch 38/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5869 - mae: 0.5997 - val_loss: 0.4006 - val_mae: 0.4880
# Epoch 39/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5623 - mae: 0.5829 - val_loss: 0.3889 - val_mae: 0.4852
# Epoch 40/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6028 - mae: 0.6098 - val_loss: 0.4052 - val_mae: 0.4995
# Epoch 41/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6041 - mae: 0.6124 - val_loss: 0.4068 - val_mae: 0.4950
# Epoch 42/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5743 - mae: 0.5862 - val_loss: 0.4018 - val_mae: 0.4989
# Epoch 43/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5675 - mae: 0.5901 - val_loss: 0.3894 - val_mae: 0.4870
# Epoch 44/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5585 - mae: 0.5859 - val_loss: 0.4705 - val_mae: 0.5391
# Epoch 45/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5620 - mae: 0.5866 - val_loss: 0.3828 - val_mae: 0.4833
# Epoch 46/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6148 - mae: 0.6157 - val_loss: 0.4354 - val_mae: 0.5148
# Epoch 47/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.6105 - mae: 0.6145 - val_loss: 0.3713 - val_mae: 0.4874
# Epoch 48/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5696 - mae: 0.5877 - val_loss: 0.3759 - val_mae: 0.4915
# Epoch 49/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5616 - mae: 0.5888 - val_loss: 0.3754 - val_mae: 0.4897
# Epoch 50/50
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5524 - mae: 0.5876 - val_loss: 0.3728 - val_mae: 0.4733
# Epoch 1/50
# 35/35 [==============================] - 1s 7ms/step - loss: 1.5222 - accuracy: 0.4718 - val_loss: 1.1286 - val_accuracy: 0.5667
# Epoch 2/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0640 - accuracy: 0.5898 - val_loss: 1.0340 - val_accuracy: 0.5458
# Epoch 3/50
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0241 - accuracy: 0.6104 - val_loss: 1.0032 - val_accuracy: 0.5604
# Epoch 4/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.9835 - accuracy: 0.6122 - val_loss: 0.9852 - val_accuracy: 0.5500
# Epoch 5/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9600 - accuracy: 0.6175 - val_loss: 0.9675 - val_accuracy: 0.5625
# Epoch 6/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9350 - accuracy: 0.6273 - val_loss: 0.9658 - val_accuracy: 0.5708
# Epoch 7/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9229 - accuracy: 0.6256 - val_loss: 0.9513 - val_accuracy: 0.5604
# Epoch 8/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8925 - accuracy: 0.6550 - val_loss: 0.9536 - val_accuracy: 0.5771
# Epoch 9/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8868 - accuracy: 0.6577 - val_loss: 0.9348 - val_accuracy: 0.5750
# Epoch 10/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8680 - accuracy: 0.6550 - val_loss: 0.9369 - val_accuracy: 0.5750
# Epoch 11/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.8616 - accuracy: 0.6595 - val_loss: 0.9343 - val_accuracy: 0.5771
# Epoch 12/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8505 - accuracy: 0.6542 - val_loss: 0.9411 - val_accuracy: 0.5646
# Epoch 13/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8536 - accuracy: 0.6533 - val_loss: 0.9333 - val_accuracy: 0.5771
# Epoch 14/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.8241 - accuracy: 0.6792 - val_loss: 0.9377 - val_accuracy: 0.5792
# Epoch 15/50
# 35/35 [==============================] - 0s 3ms/step - loss: 0.8023 - accuracy: 0.6819 - val_loss: 0.9403 - val_accuracy: 0.5708
